# %%
from Univariate import Univariate

# %%
import pandas as pd

# %%
dataset=pd.read_csv("Placement.csv")

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
quan, qual = Univariate.quanqual(dataset)

# %%
quan
# Out:
# ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
qual
# Out:
# ['gender',
#  'ssc_b',
#  'hsc_b',
#  'hsc_s',
#  'degree_t',
#  'workex',
#  'specialisation',
#  'status']

# %% [markdown]
# # Central Tendency

# %%
dataset["ssc_p"].mean()
# Out:
# 67.30339534883721

# %%
dataset["ssc_p"].median()
# Out:
# 67.0

# %%
dataset["ssc_p"].mode()[0]
# Out:
# 62.0

# %%
dataset.describe()
# Out:
#             sl_no       ssc_p       hsc_p    degree_p     etest_p       mba_p  \
# count  215.000000  215.000000  215.000000  215.000000  215.000000  215.000000
# mean   108.000000   67.303395   66.333163   66.370186   72.100558   62.278186
# std     62.209324   10.827205   10.897509    7.358743   13.275956    5.833385
# min      1.000000   40.890000   37.000000   50.000000   50.000000   51.210000
# 25%     54.500000   60.600000   60.900000   61.000000   60.000000   57.945000
# 50%    108.000000   67.000000   65.000000   66.000000   71.000000   62.000000
# 75%    161.500000   75.700000   73.000000   72.000000   83.500000   66.255000
# max    215.000000   89.400000   97.700000   91.000000   98.000000   77.890000
#
#               salary
# count     148.000000
# mean   288655.405405
# std     93457.452420
# min    200000.000000
# 25%    240000.000000
# 50%    265000.000000
# 75%    300000.000000
# max    940000.000000

# %%
descriptive=pd.DataFrame()

# %%
descriptive
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
descriptive=pd.DataFrame(index=["Mean","Median","Mode"],columns=quan)

# %%
descriptive
# Out:
#        sl_no ssc_p hsc_p degree_p etest_p mba_p salary
# Mean     NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Median   NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Mode     NaN   NaN   NaN      NaN     NaN   NaN    NaN

# %%
descriptive["ssc_p"]["Median"]=0
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_18796\801119026.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   descriptive["ssc_p"]["Median"]=0

# %%
descriptive
# Out:
#        sl_no ssc_p hsc_p degree_p etest_p mba_p salary
# Mean     NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Median   NaN     0   NaN      NaN     NaN   NaN    NaN
# Mode     NaN   NaN   NaN      NaN     NaN   NaN    NaN

# %%
descriptive=pd.DataFrame(index=["Mean","Median","Mode"],columns=quan)
for columnName in quan:
    descriptive[columnName]["Mean"]=dataset[columnName].mean()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_18796\1222842922.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   descriptive[columnName]["Mean"]=dataset[columnName].mean()

# %%
descriptive
# Out:
#         sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean    108.0  67.303395  66.333163  66.370186  72.100558  62.278186
# Median    NaN        NaN        NaN        NaN        NaN        NaN
# Mode      NaN        NaN        NaN        NaN        NaN        NaN
#
#                salary
# Mean    288655.405405
# Median            NaN
# Mode              NaN

# %%
descriptive=pd.DataFrame(index=["Mean","Median","Mode"],columns=quan)
for columnName in quan:
    descriptive[columnName]["Mean"]=dataset[columnName].mean()
    descriptive[columnName]["Median"]=dataset[columnName].median()
    descriptive[columnName]["Mode"]=dataset[columnName].mode()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_18796\2423887700.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   descriptive[columnName]["Mean"]=dataset[columnName].mean()
# ...

# %%
descriptive
# Out:
#                                                     sl_no  \
# Mean                                                108.0
# Median                                              108.0
# Mode    0        1
# 1        2
# 2        3
# 3        4
# 4 ...
#
#                                         ssc_p  \
# Mean                                67.303395
# Median                                   67.0
# Mode    0    62.0
# Name: ssc_p, dtype: float64
#
#                                         hsc_p  \
# Mean                                66.333163
# Median                                   65.0
# Mode    0    63.0
# Name: hsc_p, dtype: float64
#
#                                         degree_p  \
# Mean                                   66.370186
# Median                                      66.0
# Mode    0    65.0
# Name: degree_p, dtype: float64
#
#                                         etest_p  \
# Mean                                  72.100558
# ...

# %%
descriptive=pd.DataFrame(index=["Mean","Median","Mode"],columns=quan)
for columnName in quan:
    descriptive[columnName]["Mean"]=dataset[columnName].mean()
    descriptive[columnName]["Median"]=dataset[columnName].median()
    descriptive[columnName]["Mode"]=dataset[columnName].mode()[0]
descriptive
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_18796\2683795080.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   descriptive[columnName]["Mean"]=dataset[columnName].mean()
# ...

# %%
import numpy as np

# %%
np.percentile(dataset["ssc_p"],25)
# Out:
# 60.599999999999994

# %%
descriptive=pd.DataFrame(index=["Mean","Median","Mode","25%"],columns=quan)
for columnName in quan:
    descriptive[columnName]["Mean"]=dataset[columnName].mean()
    descriptive[columnName]["Median"]=dataset[columnName].median()
    descriptive[columnName]["Mode"]=dataset[columnName].mode()[0]
    descriptive[columnName]["25%"]=np.percentile(dataset[columnName],25)
    
descriptive
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_18796\2741553266.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   descriptive[columnName]["Mean"]=dataset[columnName].mean()
# ...

# %%
descriptive=pd.DataFrame(index=["Mean","Median","Mode","Q1:25%","Q2:50%","Q3:75%","99%","Q4:100%"],columns=quan)
for columnName in quan:
    descriptive[columnName]["Mean"]=dataset[columnName].mean()
    descriptive[columnName]["Median"]=dataset[columnName].median()
    descriptive[columnName]["Mode"]=dataset[columnName].mode()[0]
    descriptive[columnName]["Q1:25%"]=dataset.describe()[columnName]["25%"]
    descriptive[columnName]["Q2:50%"]=dataset.describe()[columnName]["50%"]
    descriptive[columnName]["Q3:75%"]=dataset.describe()[columnName]["75%"]
    
    descriptive[columnName]["99%"]=np.percentile(dataset[columnName],99)
    descriptive[columnName]["Q4:100%"]=dataset.describe()[columnName]["max"]
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_18796\1894647793.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   descriptive[columnName]["Mean"]=dataset[columnName].mean()
# ...

# %%
descriptive
# Out:
#           sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean      108.0  67.303395  66.333163  66.370186  72.100558  62.278186
# Median    108.0       67.0       65.0       66.0       71.0       62.0
# Mode          1       62.0       63.0       65.0       60.0       56.7
# Q1:25%     54.5       60.6       60.9       61.0       60.0     57.945
# Q2:50%    108.0       67.0       65.0       66.0       71.0       62.0
# Q3:75%    161.5       75.7       73.0       72.0       83.5     66.255
# 99%      212.86       87.0      91.86      83.86       97.0    76.1142
# Q4:100%   215.0       89.4       97.7       91.0       98.0      77.89
#
#                 salary
# Mean     288655.405405
# Median        265000.0
# Mode          300000.0
# Q1:25%        240000.0
# Q2:50%        265000.0
# Q3:75%        300000.0
# 99%                NaN
# Q4:100%       940000.0

# %%
#Percentile Report:

#25th Percentile of 10th Pass Marks exist at 60.6
#50th Percentile of 10th Pass Marks exist at 67.0
#Therefore 25% of the Students has only 7% increase in their marks

#75th Percentile of 10th Pass Marks exist at 75.7
#Therefore 25% of further Students has only 8% increase in their marks

#99th Percentile of 10th Pass Marks exist at 87.0
#Therefore 24% of further Students has 12% increase in their marks

#100th Percentile of 10th Pass Marks exist at 89.4
#Therefore 1% of further Students has 2% increase in their marks

# %%
descriptive=pd.DataFrame(index=["Mean","Median","Mode","Q1:25%","Q2:50%","Q3:75%","99%","Q4:100%","IQR",
                                "1.5Rule","LesserOutlierRange","GreaterOutlierRange","Min","Max"],columns=quan)
for columnName in quan:
    descriptive[columnName]["Mean"]=dataset[columnName].mean()
    descriptive[columnName]["Median"]=dataset[columnName].median()
    descriptive[columnName]["Mode"]=dataset[columnName].mode()[0]
    descriptive[columnName]["Q1:25%"]=dataset.describe()[columnName]["25%"]
    descriptive[columnName]["Q2:50%"]=dataset.describe()[columnName]["50%"]
    descriptive[columnName]["Q3:75%"]=dataset.describe()[columnName]["75%"]
    
    descriptive[columnName]["99%"]=np.percentile(dataset[columnName],99)
    descriptive[columnName]["Q4:100%"]=dataset.describe()[columnName]["max"]

    descriptive[columnName]["IQR"]=descriptive[columnName]["Q3:75%"]-descriptive[columnName]["Q1:25%"]
    descriptive[columnName]["1.5Rule"]=1.5*descriptive[columnName]["IQR"]
    
    descriptive[columnName]["LesserOutlierRange"]=descriptive[columnName]["Q1:25%"]-descriptive[columnName]["1.5Rule"]
    descriptive[columnName]["GreaterOutlierRange"]=descriptive[columnName]["Q3:75%"]+descriptive[columnName]["1.5Rule"]
    descriptive[columnName]["Min"]=dataset[columnName].min()
    descriptive[columnName]["Max"]=dataset[columnName].max()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_18796\2533232458.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   descriptive[columnName]["Mean"]=dataset[columnName].mean()
# ...

# %%
descriptive
# Out:
#                       sl_no      ssc_p      hsc_p   degree_p    etest_p  \
# Mean                  108.0  67.303395  66.333163  66.370186  72.100558
# Median                108.0       67.0       65.0       66.0       71.0
# Mode                      1       62.0       63.0       65.0       60.0
# Q1:25%                 54.5       60.6       60.9       61.0       60.0
# Q2:50%                108.0       67.0       65.0       66.0       71.0
# Q3:75%                161.5       75.7       73.0       72.0       83.5
# 99%                  212.86       87.0      91.86      83.86       97.0
# Q4:100%               215.0       89.4       97.7       91.0       98.0
# IQR                   107.0       15.1       12.1       11.0       23.5
# 1.5Rule               160.5      22.65      18.15       16.5      35.25
# LesserOutlierRange   -106.0      37.95      42.75       44.5      24.75
# GreaterOutlierRange   322.0      98.35      91.15       88.5     118.75
# ...

# %%
# descriptive["hsc_p"]["Min"] < descriptive["hsc_p"]["LesserOutlierRange"]

# %%
lesser=[]
greater=[]

for colunName in quan:
    if(descriptive[colunName]["Min"] < descriptive[colunName]["LesserOutlierRange"]):
        lesser.append(colunName)
    if(descriptive[colunName]["Max"] > descriptive[colunName]["GreaterOutlierRange"]):
        greater.append(colunName)

# %%
lesser
# Out:
# ['hsc_p']

# %%
greater
# Out:
# ['hsc_p', 'degree_p', 'salary']

# %%
for columnName in lesser:
    dataset[columnName][dataset[columnName]<descriptive[colunName]["LesserOutlierRange"]]=descriptive[colunName]["LesserOutlierRange"]
for columnName in greater:
    dataset[columnName][dataset[columnName]>descriptive[colunName]["GreaterOutlierRange"]]=descriptive[colunName]["GreaterOutlierRange"]
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_18796\2602478867.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# ...

# %%
descriptive=pd.DataFrame(index=["Mean","Median","Mode","Q1:25%","Q2:50%","Q3:75%","99%","Q4:100%","IQR",
                                "1.5Rule","LesserOutlierRange","GreaterOutlierRange","Min","Max"],columns=quan)
for columnName in quan:
    descriptive[columnName]["Mean"]=dataset[columnName].mean()
    descriptive[columnName]["Median"]=dataset[columnName].median()
    descriptive[columnName]["Mode"]=dataset[columnName].mode()[0]
    descriptive[columnName]["Q1:25%"]=dataset.describe()[columnName]["25%"]
    descriptive[columnName]["Q2:50%"]=dataset.describe()[columnName]["50%"]
    descriptive[columnName]["Q3:75%"]=dataset.describe()[columnName]["75%"]
    
    descriptive[columnName]["99%"]=np.percentile(dataset[columnName],99)
    descriptive[columnName]["Q4:100%"]=dataset.describe()[columnName]["max"]

    descriptive[columnName]["IQR"]=descriptive[columnName]["Q3:75%"]-descriptive[columnName]["Q1:25%"]
    descriptive[columnName]["1.5Rule"]=1.5*descriptive[columnName]["IQR"]
    
    descriptive[columnName]["LesserOutlierRange"]=descriptive[columnName]["Q1:25%"]-descriptive[columnName]["1.5Rule"]
    descriptive[columnName]["GreaterOutlierRange"]=descriptive[columnName]["Q3:75%"]+descriptive[columnName]["1.5Rule"]
    descriptive[columnName]["Min"]=dataset[columnName].min()
    descriptive[columnName]["Max"]=dataset[columnName].max()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_18796\252486847.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   descriptive[columnName]["Mean"]=dataset[columnName].mean()
# ...

# %%
descriptive
# Out:
#                       sl_no      ssc_p     hsc_p   degree_p    etest_p  \
# Mean                  108.0  67.303395  150000.0  66.370186  72.100558
# Median                108.0       67.0  150000.0       66.0       71.0
# Mode                      1       62.0  150000.0       65.0       60.0
# Q1:25%                 54.5       60.6  150000.0       61.0       60.0
# Q2:50%                108.0       67.0  150000.0       66.0       71.0
# Q3:75%                161.5       75.7  150000.0       72.0       83.5
# 99%                  212.86       87.0  150000.0      83.86       97.0
# Q4:100%               215.0       89.4  150000.0       91.0       98.0
# IQR                   107.0       15.1       0.0       11.0       23.5
# 1.5Rule               160.5      22.65       0.0       16.5      35.25
# LesserOutlierRange   -106.0      37.95  150000.0       44.5      24.75
# GreaterOutlierRange   322.0      98.35  150000.0       88.5     118.75
# ...

# %%
lesser=[]
greater=[]

for colunName in quan:
    if(descriptive[colunName]["Min"] < descriptive[colunName]["LesserOutlierRange"]):
        lesser.append(colunName)
    if(descriptive[colunName]["Max"] > descriptive[colunName]["GreaterOutlierRange"]):
        greater.append(colunName)

# %%
lesser
# Out:
# []

# %%
greater
# Out:
# ['degree_p']

# %%
dataset["ssc_p"].value_counts()
# Out:
# ssc_p
# 62.00    11
# 63.00    10
# 67.00     9
# 52.00     9
# 73.00     9
#          ..
# 69.70     1
# 80.92     1
# 83.00     1
# 86.50     1
# 80.60     1
# Name: count, Length: 103, dtype: int64

# %%
freqTable=pd.DataFrame(columns=["Unique_Values","Frequency","Relative_Frequency","CumSum"])

# %%
freqTable
# Out:
# Empty DataFrame
# Columns: [Unique_Values, Frequency, Relative_Frequency, CumSum]
# Index: []

# %%
freqTable["Unique_Values"]=dataset["ssc_p"].value_counts()

# %%
freqTable
# Out:
#        Unique_Values Frequency Relative_Frequency CumSum
# ssc_p
# 62.00             11       NaN                NaN    NaN
# 63.00             10       NaN                NaN    NaN
# 67.00              9       NaN                NaN    NaN
# 52.00              9       NaN                NaN    NaN
# 73.00              9       NaN                NaN    NaN
# ...              ...       ...                ...    ...
# 69.70              1       NaN                NaN    NaN
# 80.92              1       NaN                NaN    NaN
# 83.00              1       NaN                NaN    NaN
# 86.50              1       NaN                NaN    NaN
# 80.60              1       NaN                NaN    NaN
#
# [103 rows x 4 columns]

# %%
freqTable["Unique_Values"]=dataset["ssc_p"].value_counts().index
freqTable["Frequency"]=dataset["ssc_p"].value_counts().values
freqTable["Relative_Frequency"]=(freqTable["Frequency"])/103
freqTable["CumSum"]=freqTable["Relative_Frequency"].cumsum()

# %%
freqTable
# Out:
#        Unique_Values  Frequency  Relative_Frequency    CumSum
# ssc_p
# 62.00          62.00         11            0.106796  0.106796
# 63.00          63.00         10            0.097087  0.203883
# 67.00          67.00          9            0.087379  0.291262
# 52.00          52.00          9            0.087379  0.378641
# 73.00          73.00          9            0.087379  0.466019
# ...              ...        ...                 ...       ...
# 69.70          69.70          1            0.009709  2.048544
# 80.92          80.92          1            0.009709  2.058252
# 83.00          83.00          1            0.009709  2.067961
# 86.50          86.50          1            0.009709  2.077670
# 80.60          80.60          1            0.009709  2.087379
#
# [103 rows x 4 columns]

# %%
freqTable["Unique_Values"]=dataset["ssc_p"].value_counts().index
freqTable["Frequency"]=dataset["ssc_p"].value_counts().values
freqTable["Relative_Frequency"]=(freqTable["Frequency"])/103
freqTable["CumSum"]=freqTable["Relative_Frequency"].cumsum()

# %%
def freqTable(colunName,dataset):
    freqTable=pd.DataFrame(columns=["Unique_Values","Frequency","Relative_Frequency","CumSum"])
    freqTable["Unique_Values"]=dataset[colunName].value_counts().index
    freqTable["Frequency"]=dataset[colunName].value_counts().values
    freqTable["Relative_Frequency"]=(freqTable["Frequency"])/103
    freqTable["CumSum"]=freqTable["Relative_Frequency"].cumsum()
    return freqTable

# %%
freqTable("degree_p",dataset)
# Out:
#     Unique_Values  Frequency  Relative_Frequency    CumSum
# 0            65.0         20            0.194175  0.194175
# 1            66.0         13            0.126214  0.320388
# 2            72.0         12            0.116505  0.436893
# 3            64.0         11            0.106796  0.543689
# 4            58.0          9            0.087379  0.631068
# ..            ...        ...                 ...       ...
# 84           82.0          1            0.009709  2.048544
# 85           50.8          1            0.009709  2.058252
# 86           76.0          1            0.009709  2.067961
# 87           63.0          1            0.009709  2.077670
# 88           77.6          1            0.009709  2.087379
#
# [89 rows x 4 columns]

# %%
def Univariate(quan,dataset):
    descriptive=pd.DataFrame(index=["Mean","Median","Mode","Q1:25%","Q2:50%","Q3:75%","99%","Q4:100%","IQR",
                                "1.5Rule","LesserOutlierRange","GreaterOutlierRange","Min","Max","skew","kurtosis"],columns=quan)
    for columnName in quan:
        descriptive[columnName]["Mean"]=dataset[columnName].mean()
        descriptive[columnName]["Median"]=dataset[columnName].median()
        descriptive[columnName]["Mode"]=dataset[columnName].mode()[0]
        descriptive[columnName]["Q1:25%"]=dataset.describe()[columnName]["25%"]
        descriptive[columnName]["Q2:50%"]=dataset.describe()[columnName]["50%"]
        descriptive[columnName]["Q3:75%"]=dataset.describe()[columnName]["75%"]
        descriptive[columnName]["99%"]=np.percentile(dataset[columnName],99)
        descriptive[columnName]["Q4:100%"]=dataset.describe()[columnName]["max"]
    
        descriptive[columnName]["IQR"]=descriptive[columnName]["Q3:75%"]-descriptive[columnName]["Q1:25%"]
        descriptive[columnName]["1.5Rule"]=1.5*descriptive[columnName]["IQR"]
        
        descriptive[columnName]["LesserOutlierRange"]=descriptive[columnName]["Q1:25%"]-descriptive[columnName]["1.5Rule"]
        descriptive[columnName]["GreaterOutlierRange"]=descriptive[columnName]["Q3:75%"]+descriptive[columnName]["1.5Rule"]
        descriptive[columnName]["Min"]=dataset[columnName].min()
        descriptive[columnName]["Max"]=dataset[columnName].max()
        descriptive[columnName]["skew"]=dataset[columnName].skew()
        descriptive[columnName]["kurtosis"]=dataset[columnName].kurtosis()
        
    return descriptive

# %%
Univariate(quan,dataset)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_18796\2618657997.py:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   descriptive[columnName]["Mean"]=dataset[columnName].mean()
# ...

# %%
descriptive
# Out:
#                       sl_no      ssc_p     hsc_p   degree_p    etest_p  \
# Mean                  108.0  67.303395  150000.0  66.370186  72.100558
# Median                108.0       67.0  150000.0       66.0       71.0
# Mode                      1       62.0  150000.0       65.0       60.0
# Q1:25%                 54.5       60.6  150000.0       61.0       60.0
# Q2:50%                108.0       67.0  150000.0       66.0       71.0
# Q3:75%                161.5       75.7  150000.0       72.0       83.5
# 99%                  212.86       87.0  150000.0      83.86       97.0
# Q4:100%               215.0       89.4  150000.0       91.0       98.0
# IQR                   107.0       15.1       0.0       11.0       23.5
# 1.5Rule               160.5      22.65       0.0       16.5      35.25
# LesserOutlierRange   -106.0      37.95  150000.0       44.5      24.75
# GreaterOutlierRange   322.0      98.35  150000.0       88.5     118.75
# ...

# %%
dir(dataset)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__arrow_c_stream__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__dataframe_consortium_standard__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
# ...

# %%
dataset["ssc_p"].skew()
# Out:
# -0.13264949031456927

# %%
dataset["ssc_p"].kurtosis()
# Out:
# -0.6075102066986688

# %%
#def Univariate(quan,dataset):

# %%
    descriptive=pd.DataFrame(index=["Mean","Median","Mode","Q1:25%","Q2:50%","Q3:75%","99%","Q4:100%","IQR",
                                "1.5Rule","LesserOutlierRange","GreaterOutlierRange","Min","Max","skew","kurtosis"],columns=quan)
    for columnName in quan:
        descriptive[columnName]["Mean"]=dataset[columnName].mean()
        descriptive[columnName]["Median"]=dataset[columnName].median()
        descriptive[columnName]["Mode"]=dataset[columnName].mode()[0]
        descriptive[columnName]["Q1:25%"]=dataset.describe()[columnName]["25%"]
        descriptive[columnName]["Q2:50%"]=dataset.describe()[columnName]["50%"]
        descriptive[columnName]["Q3:75%"]=dataset.describe()[columnName]["75%"]
        descriptive[columnName]["99%"]=np.percentile(dataset[columnName],99)
        descriptive[columnName]["Q4:100%"]=dataset.describe()[columnName]["max"]
    
        descriptive[columnName]["IQR"]=descriptive[columnName]["Q3:75%"]-descriptive[columnName]["Q1:25%"]
        descriptive[columnName]["1.5Rule"]=1.5*descriptive[columnName]["IQR"]
        
        descriptive[columnName]["LesserOutlierRange"]=descriptive[columnName]["Q1:25%"]-descriptive[columnName]["1.5Rule"]
        descriptive[columnName]["GreaterOutlierRange"]=descriptive[columnName]["Q3:75%"]+descriptive[columnName]["1.5Rule"]
        descriptive[columnName]["Min"]=dataset[columnName].min()
        descriptive[columnName]["Max"]=dataset[columnName].max()
        descriptive[columnName]["skew"]=dataset[columnName].skew()
        descriptive[columnName]["kurtosis"]=dataset[columnName].kurtosis()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_18796\1911250574.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   descriptive[columnName]["Mean"]=dataset[columnName].mean()
# ...

# %%
descriptive
# Out:
#                       sl_no      ssc_p     hsc_p   degree_p    etest_p  \
# Mean                  108.0  67.303395  150000.0  66.370186  72.100558
# Median                108.0       67.0  150000.0       66.0       71.0
# Mode                      1       62.0  150000.0       65.0       60.0
# Q1:25%                 54.5       60.6  150000.0       61.0       60.0
# Q2:50%                108.0       67.0  150000.0       66.0       71.0
# Q3:75%                161.5       75.7  150000.0       72.0       83.5
# 99%                  212.86       87.0  150000.0      83.86       97.0
# Q4:100%               215.0       89.4  150000.0       91.0       98.0
# IQR                   107.0       15.1       0.0       11.0       23.5
# 1.5Rule               160.5      22.65       0.0       16.5      35.25
# LesserOutlierRange   -106.0      37.95  150000.0       44.5      24.75
# GreaterOutlierRange   322.0      98.35  150000.0       88.5     118.75
# ...

# %%
Univariate(quan,dataset)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_18796\2618657997.py:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   descriptive[columnName]["Mean"]=dataset[columnName].mean()
# ...

# %%
dataset["ssc_p"].var()
# Out:
# 117.22837673549229

# %%
dataset["ssc_p"].std()
# Out:
# 10.827205398231452

# %%
    descriptive=pd.DataFrame(index=["Mean","Median","Mode","Q1:25%","Q2:50%","Q3:75%","99%","Q4:100%","IQR",
                                "1.5Rule","LesserOutlierRange","GreaterOutlierRange","Min","Max","skew",
                                    "kurtosis","Var","Std"],columns=quan)
    for columnName in quan:
        descriptive[columnName]["Mean"]=dataset[columnName].mean()
        descriptive[columnName]["Median"]=dataset[columnName].median()
        descriptive[columnName]["Mode"]=dataset[columnName].mode()[0]
        descriptive[columnName]["Q1:25%"]=dataset.describe()[columnName]["25%"]
        descriptive[columnName]["Q2:50%"]=dataset.describe()[columnName]["50%"]
        descriptive[columnName]["Q3:75%"]=dataset.describe()[columnName]["75%"]
        descriptive[columnName]["99%"]=np.percentile(dataset[columnName],99)
        descriptive[columnName]["Q4:100%"]=dataset.describe()[columnName]["max"]
    
        descriptive[columnName]["IQR"]=descriptive[columnName]["Q3:75%"]-descriptive[columnName]["Q1:25%"]
        descriptive[columnName]["1.5Rule"]=1.5*descriptive[columnName]["IQR"]
        
        descriptive[columnName]["LesserOutlierRange"]=descriptive[columnName]["Q1:25%"]-descriptive[columnName]["1.5Rule"]
        descriptive[columnName]["GreaterOutlierRange"]=descriptive[columnName]["Q3:75%"]+descriptive[columnName]["1.5Rule"]
        descriptive[columnName]["Min"]=dataset[columnName].min()
        descriptive[columnName]["Max"]=dataset[columnName].max()
        descriptive[columnName]["skew"]=dataset[columnName].skew()
        descriptive[columnName]["kurtosis"]=dataset[columnName].kurtosis()
        descriptive[columnName]["Var"]=dataset[columnName].var()
        descriptive[columnName]["Std"]=dataset[columnName].std()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_18796\2794568348.py:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   descriptive[columnName]["Mean"]=dataset[columnName].mean()
# ...

# %%
descriptive
# Out:
#                          sl_no       ssc_p     hsc_p   degree_p     etest_p  \
# Mean                     108.0   67.303395  150000.0  66.370186   72.100558
# Median                   108.0        67.0  150000.0       66.0        71.0
# Mode                         1        62.0  150000.0       65.0        60.0
# Q1:25%                    54.5        60.6  150000.0       61.0        60.0
# Q2:50%                   108.0        67.0  150000.0       66.0        71.0
# Q3:75%                   161.5        75.7  150000.0       72.0        83.5
# 99%                     212.86        87.0  150000.0      83.86        97.0
# Q4:100%                  215.0        89.4  150000.0       91.0        98.0
# IQR                      107.0        15.1       0.0       11.0        23.5
# 1.5Rule                  160.5       22.65       0.0       16.5       35.25
# LesserOutlierRange      -106.0       37.95  150000.0       44.5       24.75
# ...
